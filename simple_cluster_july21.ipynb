# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
train_merged = pd.read_csv('data/chunk_33_prod.csv', usecols=['Cliente_ID', 'Producto_ID', 'Demanda_uni_equil', 'Venta_hoy'])

# %%
train_merged.head()
# Out:
#    Cliente_ID  Producto_ID  Venta_hoy  Demanda_uni_equil
# 0       15766          325       8.15                  1
# 1      198780          325      24.45                  3
# 2      198780          325      40.75                  5
# 3      198780          325      48.90                  6
# 4      818913          325       8.15                  1

# %%
train_merged[train_merged['Cliente_ID'] == 198780]
# Out:
#         Cliente_ID  Producto_ID  Venta_hoy  Demanda_uni_equil
# 1           198780          325      24.45                  3
# 2           198780          325      40.75                  5
# 3           198780          325      48.90                  6
# 97022       198780          328      48.90                  6
# 97023       198780          328      40.75                  5
# 97024       198780          328      24.45                  3
# 210561      198780          323      24.45                  3
# 210562      198780          323      24.45                  3
# 210563      198780          323      40.75                  5
# 210564      198780          323      48.90                  6

# %%
train_merged['Producto_ID'] = 1

# %%
train_merged.head()
# Out:
#    Cliente_ID  Producto_ID  Venta_hoy  Demanda_uni_equil
# 0       15766            1       8.15                  1
# 1      198780            1      24.45                  3
# 2      198780            1      40.75                  5
# 3      198780            1      48.90                  6
# 4      818913            1       8.15                  1

# %%
client_group = train_merged.groupby([train_merged['Cliente_ID']], as_index=False).sum()

# %%
client_group.head()
# Out:
#    Cliente_ID  Producto_ID  Venta_hoy  Demanda_uni_equil
# 0         772            2      29.60                  8
# 1        2015            1      14.80                  4
# 2        2025            4     124.92                 29
# 3        2029            2      51.80                 14
# 4        2059            1      22.20                  6

# %%
client_group[client_group['Cliente_ID'] == 198780]
# Out:
#        Cliente_ID  Producto_ID  Venta_hoy  Demanda_uni_equil
# 24566      198780           10     366.75                 45

# %%
plt.scatter(client_group['Producto_ID'], client_group['Demanda_uni_equil'], s=50)

# %%
plt.scatter(client_group['Venta_hoy'], client_group['Demanda_uni_equil'], s=50)
plt.xlim(0, 50000)
plt.ylim(0, 2000)
# Out:
# (0, 2000)

# %%
plt.scatter(client_group['Venta_hoy'], client_group['Producto_ID'], s=50)
plt.xlim(0,25000)
plt.ylim(0,10)
# Out:
# (0, 10)

# %%
from mpl_toolkits.mplot3d import Axes3D

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

x = client_group['Producto_ID']
y = client_group['Venta_hoy']
z = client_group['Demanda_uni_equil']

ax.scatter(x, y, z, c='r', marker='o')

ax.set_xlabel('X Label')
ax.set_ylabel('Y Label')
ax.set_zlabel('Z Label')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-13-75285daa48a2> in <module>()
# ----> 1 from mpl_toolkits.mplot3d import Axes3D
#       2
#       3 fig = plt.figure()
#       4 ax = fig.add_subplot(111, projection='3d')
#       5
#
# /Users/sbajaj/Library/Python/2.7/lib/python/site-packages/mpl_toolkits/mplot3d/__init__.py in <module>()
#       2                         unicode_literals)
#       3
# ----> 4 from matplotlib.externals import six
#       5
#       6 from .axes3d import Axes3D
#
# ImportError: No module named externals

# %%
train_merged = pd.read_csv('data/chunk_33_prod.csv', usecols=['Cliente_ID', 'Producto_ID', 'Demanda_uni_equil', 'Venta_hoy'])

# %%
train_merged['Cliente_ID'] = 1
train_merged.head()
# Out:
#    Cliente_ID  Producto_ID  Venta_hoy  Demanda_uni_equil
# 0           1          325       8.15                  1
# 1           1          325      24.45                  3
# 2           1          325      40.75                  5
# 3           1          325      48.90                  6
# 4           1          325       8.15                  1

# %%
train_merged['Producto_ID'].unique()
# Out:
# array([325, 328, 145, 323, 214, 202,  73, 163, 205, 108, 100,  72, 303,
#        141, 357, 160, 183, 162, 123, 306, 157,  53, 106, 107, 412, 217,
#        134, 135, 151, 132, 131,  41, 122])

# %%
product_group = train_merged.groupby([train_merged['Producto_ID']], as_index=False).sum()
product_group.head()
# Out:
#    Producto_ID  Cliente_ID       Venta_hoy  Demanda_uni_equil
# 0           41          61    406469.25000              22414
# 1           53         114    474559.71000              33185
# 2           72      146204   2668400.26000             715843
# 3           73      218851  15347261.91002             698935
# 4          100         124     22167.80000               1093

# %%
product_group.shape
# Out:
# (33, 4)

# %%
plt.scatter(product_group['Cliente_ID'], product_group['Demanda_uni_equil'], s=50)

# %%
plt.scatter(product_group['Cliente_ID'], product_group['Venta_hoy'], s=50)

# %%
plt.scatter(product_group['Venta_hoy'], product_group['Demanda_uni_equil'], s=50)
